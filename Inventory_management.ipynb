# %%
record={
        19001:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"6GB","Battery":"3000mH","Color":"Black","Price":15000,"Qty":100},
        19002:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"6GB","Battery":"3000mH","Color":"Blue","Price":15000,"Qty":100},
        19003:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"8GB","Battery":"3000mH","Color":"Black","Price":16000,"Qty":100},
        19004:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"8GB","Battery":"3000mH","Color":"Blue","Price":16000,"Qty":100},
        19005:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":17000,"Qty":100},
        19006:{"MobileName":"SamsungM30","Memory":"128GB","Ram":"12GB","Battery":"4500mH","Color":"Blue","Price":17000,"Qty":100},
        19007:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"6GB","Battery":"4500mH","Color":"Black","Price":18000,"Qty":100},
        19008:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"6GB","Battery":"4500mH","Color":"Blue","Price":18000,"Qty":100},
        19009:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Black","Price":20000,"Qty":100},
        19010:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Blue","Price":20000,"Qty":100},
        19011:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":20500,"Qty":100},
        19012:{"MobileName":"SamsungM30","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Blue","Price":20500,"Qty":100},
        19013:{"MobileName":"Vivo","Memory":"128GB","Ram":"6GB","Battery":"3000mH","Color":"White","Price":15000,"Qty":100},
        19014:{"MobileName":"Vivo","Memory":"128GB","Ram":"6GB","Battery":"3000mH","Color":"Gold","Price":15500,"Qty":100},
        19015:{"MobileName":"Vivo","Memory":"128GB","Ram":"8GB","Battery":"4500mH","Color":"White","Price":17000,"Qty":100},
        19016:{"MobileName":"Vivo","Memory":"128GB","Ram":"8GB","Battery":"4500mH","Color":"Gold","Price":17500,"Qty":100},
        19017:{"MobileName":"Vivo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"White","Price":19000,"Qty":100},
        19018:{"MobileName":"Vivo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Black","Price":19500,"Qty":100},
        19019:{"MobileName":"Vivo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Gold","Price":19500,"Qty":100},
        19020:{"MobileName":"Vivo","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":21000,"Qty":100},
        19021:{"MobileName":"Vivo","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Gold","Price":21000,"Qty":100},
        19022:{"MobileName":"Oppo","Memory":"128GB","Ram":"6GB","Battery":"4500mH","Color":"Gold","Price":17000,"Qty":100},
        19023:{"MobileName":"Oppo","Memory":"128GB","Ram":"6GB","Battery":"4500mH","Color":"White","Price":17000,"Qty":100},
        19024:{"MobileName":"Oppo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Gold","Price":19000,"Qty":100},
        19025:{"MobileName":"Oppo","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"White","Price":19000,"Qty":100},
        19026:{"MobileName":"Oppo","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Gold","Price":21000,"Qty":100},
        19027:{"MobileName":"Oppo","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"White","Price":21000,"Qty":100},
        19028:{"MobileName":"Oneplusnord","Memory":"256GB","Ram":"8GB","Battery":"4500mH","Color":"Black","Price":38000,"Qty":100},
        19029:{"MobileName":"Oneplusnord","Memory":"256GB","Ram":"12GB","Battery":"4500mH","Color":"Black","Price":40000,"Qty":100},
        19030:{"MobileName":"Moto","Memory":"128GB","Ram":"6GB","Battery":"4500mH","Color":"Black","Price":15000,"Qty":100},
}

# %%
import json
js=json.dumps(record)
pd=open('record.json','w')
pd.write(js)
pd.close()

# %% [markdown]
# **Adding** **New** **item** **into** **Inventory**

# %%
mobilename=input("mobilename: ")
memory=input("memory: ")
ram=input("ram: ")
battery=input("battery: ")
color=input("color: ")
price=int(input("price: "))
qty=int(input("No of items want to add into Inventory: "))
for j in record.keys():
  if record[j]["MobileName"]==mobilename and record[j]["Memory"]==memory and record[j]["Ram"]==ram and record[j]["Battery"]==battery and record[j]["Color"]==color:
    record[j]["Qty"]=record[j]["Qty"]+qty
    break
else:
  record[19000+len(record)+1]={"MobileName":mobilename,"Memory":memory,"Ram":ram,"Battery":battery,"Color":color,"Price":price,"Qty":qty}
import json
js=json.dumps(record)
pd=open('record.json','w')
pd.write(js)
pd.close()
# Out:
# mobilename: LG
# memory: 128GB
# ram: 4GB
# battery: 3000mAH
# color: Black
# price: 10000
# No of items want to add into Inventory: 54

# %%
record
# Out:
# {19001: {'Battery': '3000mH',
#   'Color': 'Black',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 15000,
#   'Qty': 100,
#   'Ram': '6GB'},
#  19002: {'Battery': '3000mH',
#   'Color': 'Blue',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 15000,
#   'Qty': 100,
#   'Ram': '6GB'},
#  19003: {'Battery': '3000mH',
#   'Color': 'Black',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 16000,
#   'Qty': 100,
#   'Ram': '8GB'},
#  19004: {'Battery': '3000mH',
#   'Color': 'Blue',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 16000,
#   'Qty': 100,
#   'Ram': '8GB'},
#  19005: {'Battery': '4500mH',
#   'Color': 'Black',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 17000,
#   'Qty': 100,
#   'Ram': '12GB'},
#  19006: {'Battery': '4500mH',
#   'Color': 'Blue',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 17000,
#   'Qty': 100,
#   'Ram': '12GB'},
# ...

# %% [markdown]
# **Purchase**

# %%
N=int(input("Enter the Quantity: "))
TotalPrice=0
mobilename=input("mobilename: ")
memory=input("memory: ")
ram=input("ram: ")
battery=input("battery: ")
color=input("color: ")
for j in record.keys():
  if record[j]["MobileName"]==mobilename and record[j]["Memory"]==memory and record[j]["Ram"]==ram and record[j]["Battery"]==battery and record[j]["Color"]==color:
    if record[j]["Qty"]>=N:
      print(N*record[j]["Price"])
      print("Product-Id: "+str(j))
      record[j]["Qty"]=record[j]["Qty"]-N
    else:
      print(str(record[j]["Qty"])+" Mobiles are Available")
      print(record[j]["Price"]*record[j]["Qty"])
      print("Product-Id: "+str(j))
      record[j]["Qty"]=0
    break
else:
  print("Model Not Found")
# Out:
# Enter the Quantity: 10
# mobilename: LG
# memory: 128GB
# ram: 4GB
# battery: 3000mAH
# color: Black
# 100000
# Product-Id: 19031

# %%
record
# Out:
# {19001: {'Battery': '3000mH',
#   'Color': 'Black',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 15000,
#   'Qty': 100,
#   'Ram': '6GB'},
#  19002: {'Battery': '3000mH',
#   'Color': 'Blue',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 15000,
#   'Qty': 100,
#   'Ram': '6GB'},
#  19003: {'Battery': '3000mH',
#   'Color': 'Black',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 16000,
#   'Qty': 100,
#   'Ram': '8GB'},
#  19004: {'Battery': '3000mH',
#   'Color': 'Blue',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 16000,
#   'Qty': 100,
#   'Ram': '8GB'},
#  19005: {'Battery': '4500mH',
#   'Color': 'Black',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 17000,
#   'Qty': 100,
#   'Ram': '12GB'},
#  19006: {'Battery': '4500mH',
#   'Color': 'Blue',
#   'Memory': '128GB',
#   'MobileName': 'SamsungM30',
#   'Price': 17000,
#   'Qty': 100,
#   'Ram': '12GB'},
# ...

# %% [markdown]
# **Updating** **Inventory** **after** **Purchase**

# %%
import json
js=json.dumps(record)
pd=open('record.json','w')
pd.write(js)
pd.close()

# %% [markdown]
# **Sales** **json**

# %%
sales={
       1:{"Product_id":19001,"Quantity":4,"Amount":60000},
       2:{"Product_id":19002,"Quantity":1,"Amount":15000},
       3:{"Product_id":19003,"Quantity":3,"Amount":48000},
       4:{"Product_id":19004,"Quantity":2,"Amount":32000},
       5:{"Product_id":19005,"Quantity":5,"Amount":85000}
       }
import json
js=json.dumps(sales)
pd=open('sales.json','w')
pd.write(js)
pd.close()

# %%
product_id=int(input("product_id: "))
quantity=int(input("quantity: "))
sales[len(sales)+1]={"Product_id":product_id,"Quantity":quantity,"Amount":record[product_id]["Price"]*quantity}
import json
js=json.dumps(sales)
pd=open('sales.json','w')
pd.write(js)
pd.close()
# Out:
# product_id: 19031
# quantity: 4

# %%
sales
# Out:
# {1: {'Amount': 60000, 'Product_id': 19001, 'Quantity': 4},
#  2: {'Amount': 15000, 'Product_id': 19002, 'Quantity': 1},
#  3: {'Amount': 48000, 'Product_id': 19003, 'Quantity': 3},
#  4: {'Amount': 32000, 'Product_id': 19004, 'Quantity': 2},
#  5: {'Amount': 85000, 'Product_id': 19005, 'Quantity': 5},
#  6: {'Amount': 40000, 'Product_id': 19031, 'Quantity': 4}}
